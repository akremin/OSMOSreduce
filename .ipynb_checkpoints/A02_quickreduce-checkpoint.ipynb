# %% [markdown]
# Basic Walkthrough:
#      1) Define everything
#      2) Create master bias file, Save master bias file
#      3) Open all other files, sub master bias, save  (*c?.b.fits)
#      4) Remove cosmics from all file types except bias  (*c?.bc.fits)
#      5) Open flats and create master skyflat file, save
#      6) Open all remainging types and divide out master flat, then save  (*c?.bcf.fits)
#      7) Open all remaining types and stitch together, save  (*full.bcf.fits)
#      8) Use fibermap files to determine aperatures
#      9) Use aperatures to cut out same regions in thar,comp,science
#      10) Save all 256 to files with their header tagged name in filename, along with fiber num
#      11) Assume no curvature within tiny aperature region; fit profile to 2d spec and sum to 1d
#      12) Fit the lines in comp spectra, save file and fit solution
#      13) Try to fit lines in thar spectra, save file and fit solution
#      14) Apply to science spectra

# %%
import os
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Define input file numbers and other required information
#
# Ex:
#
#     Bias 597-626
#     ThAr 627,635
#     NeHgArXe 628,629,636,637
#     Science 631-634
#     Fibermaps 573-577

# %%
biass = np.arange(597,626+1).astype(int)
thar_lamps = np.asarray([627,635])
comp_lamps = np.asarray([628,629,636,637])
twiflats = np.arange(582,591+1).astype(int)
sciences = np.arange(631,634+1).astype(int)
fibermaps = np.arange(573,577+1).astype(int)

# %%
instrument = 'M2FS'
mask_name = 'A02'
cal_lamp = ['Xenon', 'Argon', 'HgNe']  # 'Xenon','Argon','Neon', 'HgNe'
cameras = ['r']
opamps = [1,2,3,4]

# %%
path_to_masks = os.path.abspath('../../OneDrive/Research/M2FSReductions')
mask_subdir = mask_name
raw_data_subdir =  'raw_data'
raw_filename_template = '{cam}{filenum:04d}c{opamp}.fits'

# %%
make_debug_plots = False
print_headers = True
cut_bias_cols = True

# %%
do_bias = False
do_cr   = False
do_flat = True
do_stitch = True
do_apcut = True
do_2dto1d = True
do_wavecalib = True
do_combine = True
do_zfit = True

# %% [markdown]
# ###         Beginning of Code

# %%
date = np.datetime_as_string(np.datetime64('today', 'D'))

# %%
mask_dir = os.path.join(path_to_masks,mask_subdir)

# %%
raw_data_dir =    os.path.join(mask_dir, raw_data_subdir)
product_dir =     os.path.join(mask_dir,'data_products')
stitched_dir =    os.path.join(mask_dir,'stitched')
twod_dir =        os.path.join(mask_dir,'twods')
oned_dir =        os.path.join(mask_dir,'oneds')
calibrated_dir =  os.path.join(mask_dir,'calibrated_oned')
summedspec_dir =  os.path.join(mask_dir,'final_oned')
zfit_dir =        os.path.join(mask_dir,'zfits')

for folder in [ raw_data_dir, product_dir, stitched_dir, twod_dir, 
    oned_dir, calibrated_dir, summedspec_dir, zfit_dir]:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
fibermap_array_dict, fibermap_header_dict = None,None
twiflat_array_dict, twiflat_header_dict = None,None
bias_array_dict, bias_header_dict = None,None

# %%
headers = {}
data = {}
master_aux_data = {}
master_aux_headers = {}

# %%
filenumbers = {'bias':biass, 'thar':thar_lamps, 'comp': comp_lamps,
               'twiflat':twiflats, 'science': sciences, 'fibmap': fibermaps}

# %%
base_file_template =          '{cam}_{imtype}_{filenum:04d}_{maskname}_'
valadded_filename_template =  base_file_template+'c{opamp}{tags}.fits'
stitched_filename_template =  base_file_template+'stitched{tags}.fits'
twod_filename_template =      base_file_template+'{fibername}_2d{tags}.fits'
oned_filename_template =      base_file_template+'{fibername}_1d{tags}.fits'
combined_filename_template =  base_file_template+'{fibername}_1d{tags}.fits'

master_valadded_fname_template =  '{cam}_master{imtype}_{maskname}_c{opamp}{tags}.fits'
master_stitched_fname_template =  '{cam}_master{imtype}_{maskname}_stitched{tags}.fits'

# %%
common_func_vals = {    'maskname':      mask_name,
                        'cameras':       cameras,
                        'opamps':        opamps,         
                        'datadir':       raw_data_dir,
                        'template':      raw_filename_template,
                        'tags':          ''                      }

# %%
from quickreduce_funcs import get_all_filedata

if do_bias:
    data, headers = get_all_filedata(filenum_dict=filenumbers,
                                      cut_bias_cols=cut_bias_cols,
                                      **common_func_vals)
    
    if bias_array_dict is None or 'bias' in data.keys():
        bias_array_dict = data.pop('bias')
        bias_header_dict = headers.pop('bias')
    else:
        print("Can't find the bias data!")

# %%
from quickreduce_funcs import debug_plots, scrub_header

if do_bias:
    master_bias_data_dict = {}
    master_bias_header_dict = {}
    for camera,camera_bias_dict in bias_array_dict.items():
        master_camera_bias_data_dict = {}
        master_camera_bias_header_dict = {}
        for opamp,opampdict in camera_bias_dict.items():
            opamparray = np.asarray(list(opampdict.values()))
            if make_debug_plots:
                debug_plots(opamparray,camera, opamp)
            opamparray = np.median(opamparray,axis=0)
            header = list(bias_header_dict[camera][opamp].values())[0]
            header = scrub_header(header,opamparray.shape)
            header.add_history("Median Master Bias done by quickreduce on {}".format(date))
            outhdu = fits.PrimaryHDU(data=opamparray ,header=header)
            outname = master_valadded_fname_template.format(cam=camera, imtype='bias',maskname=mask_name, 
                                                            opamp=opamp,tags=common_func_vals['tags'])
            outhdu.writeto(os.path.join(common_func_vals['datadir'], outname) ,overwrite=True)
            master_camera_bias_data_dict[opamp] = opamparray
            master_camera_bias_header_dict[opamp] = header
        master_bias_data_dict[camera] = master_camera_bias_data_dict
        master_bias_header_dict[camera] = master_camera_bias_header_dict
        print("Completed generation of master bias")
        print("Results saved to {}".format(common_func_vals['datadir']))
        del bias_array_dict, bias_header_dict
# else:
#     ## load in master bias
#     print("Loaded master bias")
#     print("Loaded from {}".format(common_func_vals['datadir']))
    
# master_aux_data['bias'] = master_bias_data_dict
# master_aux_headers['bias'] = master_bias_header_dict

filenumbers.pop('bias')
# Out:
# Completed generation of master bias
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\raw_data
# array([597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609,
#        610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622,
#        623, 624, 625, 626])

# %%
common_func_vals['datadir']= product_dir
common_func_vals['template'] = valadded_filename_template
common_func_vals['tags'] = '.b'

# %%
if do_bias:
    filenames = {}
    for datatype,filenums in filenumbers.items():
        filenames[datatype] = {}
        datadict = data[datatype]
        headerdict = headers[datatype]
        for camera,camera_data_dict in datadict.items():
            for opamp,opamparrays in camera_data_dict.items():
                master_bias = master_bias_data_dict[camera][opamp]
                for filenum in filenums:
                    opamparray = opamparrays[filenum].astype(float)
                    header = headerdict[camera][opamp][filenum]
                    opamparray -= master_bias.astype(float)
                    header = scrub_header(header,opamparray.shape)
                    header.add_history("Bias Subtracted done by quickreduce on {}".format(date))
                    outhdu = fits.PrimaryHDU(data=opamparray ,header=header)  
                    outname = valadded_filename_template.format(cam=camera,imtype=datatype, maskname=mask_name,
                                                                opamp=opamp,filenum=filenum,tags=common_func_vals['tags'])
                    outhdu.writeto(os.path.join(common_func_vals['datadir'] ,outname) ,overwrite=True)           
                    headerdict[camera][opamp][filenum] = header
                    datadict[camera][opamp][filenum] = opamparray
        print("Completed bias subtraction for {}".format(datatype))
        print("Results saved to {}".format(common_func_vals['datadir']))
# Out:
# Completed bias subtraction for thar
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products
# Completed bias subtraction for comp
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products
# Completed bias subtraction for twiflat
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products
# Completed bias subtraction for science
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products
# Completed bias subtraction for fibmap
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products

# %%
import PyCosmic

old_tag = common_func_vals['tags']
new_tag = common_func_vals['tags']+'c'
    
if do_cr:
    if len(data.keys()) == 0:
        data, headers = get_all_filedata( filenum_dict=filenumbers, **common_func_vals )
    for datatype in data.keys():
        for camera in data[datatype].keys():
            for opamp in data[datatype][camera].keys():
                for filenum in filenumbers[datatype]:
                    filename = valadded_filename_template.format(cam=camera, imtype=datatype, maskname=mask_name,
                                                                 opamp=opamp, filenum=filenum, tags=old_tag)
                    filename = os.path.join(common_func_vals['datadir'],filename)
                    savefile = filename.replace(old_tag+'.fits',new_tag+'.fits')
                    maskfile = filename.replace(old_tag+'.fits',old_tag+'.crmask.fits')
                    print("\nFor image type: {}, shoe: {},  opamp: {}, filenum: {}".format(datatype,camera,opamp,filenum))
                    outdat,pycosmask,pyheader = PyCosmic.detCos(filename,maskfile,savefile,rdnoise='ENOISE',sigma_det=8,
                                                                gain='EGAIN',verbose=True,return_data=True)
                    data[datatype][camera][opamp][filenum] = outdat
                    ## Plot the image
                    plt.figure()
                    pycosmask = pycosmask - np.min(pycosmask) + 1e-4
                    plt.imshow(np.log(pycosmask),'gray',origin='lowerleft')
                    plt.savefig(maskfile.replace('.fits','.png'),dpi=1200)
                    plt.close()
                        
common_func_vals['tags'] = new_tag
del old_tag, new_tag
# Out:
# For image type: thar, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 4 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 9 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c1.b.crmask.fits
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyCosmic.lib.image]
# C:\Users\kremin\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# For image type: thar, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 33 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 55 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 61 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 61 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 61 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c1.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 23 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c2.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 19 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 21 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c2.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 18 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 25 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 26 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 27 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c3.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 19 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 36 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 41 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 42 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 42 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c3.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 3 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 3 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 3 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 3 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 3 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0627_A02_c4.b.crmask.fits
# For image type: thar, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_thar_0635_A02_c4.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 131 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 239 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 270 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 279 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 283 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c1.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 30 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 59 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 65 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 65 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 65 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c1.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 22 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 44 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 50 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 50 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 50 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c1.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 42 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 50 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 52 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 52 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c1.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 37 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 74 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 87 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 89 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 89 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c2.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 19 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 26 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 26 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 26 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c2.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 57 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 75 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 84 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 89 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c2.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 50 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 95 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 104 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 105 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 105 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c2.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 60 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 72 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 74 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 74 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c3.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 45 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 52 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 53 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 53 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c3.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 48 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 81 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 91 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 93 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 93 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c3.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 35 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 73 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 82 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 82 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 82 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c3.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 17 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 33 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 36 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 37 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 37 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0628_A02_c4.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 33 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 33 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 33 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0629_A02_c4.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 37 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 58 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 67 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 71 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 75 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0636_A02_c4.b.crmask.fits
# For image type: comp, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 24 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_comp_0637_A02_c4.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 2 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 2 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 2 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 2 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 2 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 7 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 16 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 7 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 9 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 13 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 14 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 38 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 44 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 44 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 44 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 28 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 51 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 53 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 53 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 53 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 40 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 44 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 45 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 46 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 72 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 112 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 116 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 116 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 116 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 133 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 221 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 240 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 240 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 240 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c1.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 4 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 10 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 7 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 12 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 25 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 27 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 27 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 7 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 14 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 43 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 67 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 74 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 76 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 76 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 71 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 109 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 116 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 117 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 118 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 186 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 302 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 325 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 326 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 326 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c2.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 0 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 0 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 0 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 0 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 0 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 17 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 17 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 17 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 17 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0583_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 18 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 29 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0584_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 25 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 30 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 30 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0585_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0586_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 6 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 12 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0587_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 29 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 52 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 58 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 61 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 61 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0588_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 18 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 20 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 22 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 22 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0589_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 63 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 95 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 100 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 101 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 101 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0590_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 151 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 244 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 271 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 278 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 279 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0591_A02_c3.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 6 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 10 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 10 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_twiflat_0582_A02_c4.b.crmask.fits
# For image type: twiflat, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# ...
# Start iteration 3
# Total number of detected cosmics: 28 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 28 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 28 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c1.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 16 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c1.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 12 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c1.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 1
# Convert image from ADUs to electrons using a gain factor of 0.595
# A value of 2.634 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 14 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c1.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c1.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 22 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 39 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 44 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 45 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 45 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c2.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 8 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 16 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c2.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 53 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 85 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 102 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 105 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 105 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c2.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 22 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 39 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 46 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 49 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 49 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c2.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 2
# Convert image from ADUs to electrons using a gain factor of 0.61
# A value of 2.534 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 23 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c2.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c2.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 34 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 49 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 53 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 54 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 55 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c3.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 20 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 23 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c3.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 13 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c3.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 23 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 23 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c3.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 3
# Convert image from ADUs to electrons using a gain factor of 0.615
# A value of 2.413 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 33 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 35 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 35 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 35 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c3.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c3.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 6 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 11 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 16 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 16 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0573_A02_c4.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 7 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 15 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 15 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0574_A02_c4.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 18 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 21 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 21 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0575_A02_c4.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 14 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 22 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 24 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 24 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0576_A02_c4.b.crmask.fits
# For image type: fibmap, shoe: r,  opamp: 4
# Convert image from ADUs to electrons using a gain factor of 0.602
# A value of 2.471 is used for the electron read-out noise.
# Start the detection process using 2 CPU cores.
# Start iteration 1
# Total number of detected cosmics: 9 out of 1052672 pixels
# Start iteration 2
# Total number of detected cosmics: 12 out of 1052672 pixels
# Start iteration 3
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 4
# Total number of detected cosmics: 13 out of 1052672 pixels
# Start iteration 5
# Total number of detected cosmics: 13 out of 1052672 pixels
# Cleaned image is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c4.bc.fits
# Cosmics mask is stored in file: C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products\r_fibmap_0577_A02_c4.b.crmask.fits

# %%
if do_flat:
    if len(data.keys()) == 0:
        data, headers = get_all_filedata( filenum_dict=filenumbers, **common_func_vals )
    if twiflat_array_dict is None or 'twiflat' in data.keys():
        twiflat_array_dict = data.pop('twiflat')
        twiflat_header_dict = headers.pop('twiflat')
    else:
        print("Can't find the twilight flats!")
# Out:
# Can't find the twilight flats!

# %%
if do_flat:
    common_func_vals['tags'] = common_func_vals['tags']+'f'
    master_twiflat_data_dict = {}
    master_twiflat_header_dict = {}
    for camera,camera_data_dict in twiflat_array_dict.items():
        master_camera_twiflat_data_dict = {}
        master_camera_twiflat_header_dict = {}
        for opamp,opampdict in camera_data_dict.items():
            opamparrays = np.asarray(list(opampdict.values()))
            heads = twiflat_header_dict[camera][opamp]
            header = list(heads.values())[0]
            if header['SHOE'].lower() != camera:
                print("In twiflat: Camera did not match the header's shoe variable")
            if header['OPAMP'] != opamp:
                print("In twiflat: Opamp did not match the header's opamp variable")
            opamparray = opamparrays.sum(axis=0)  
            header.add_history("Master twiflat summed by quickreduce on {}".format(date))
            header['TOTEXPT'] = np.sum([float(heads[key]['EXPTIME']) for key in heads.keys()])
            header.remove('EXPTIME')
            outhdu = fits.PrimaryHDU(data=opamparray ,header=header)  
            outname = master_valadded_fname_template.format(cam=camera, imtype="twilightflat", 
                                                            maskname=mask_name, opamp=opamp, 
                                                            tags=common_func_vals['tags'])
            outhdu.writeto(os.path.join(common_func_vals['datadir'] ,outname) ,overwrite=True)
            master_camera_twiflat_data_dict[opamp] = opamparray
            master_camera_twiflat_header_dict[opamp] = header
            if make_debug_plots:
                typical_sep = np.mean(opamparrays[0,:,:])- np.mean(opamparrays[-1,:,:])
                if typical_sep < 10:
                    typical_sep = 10
                debug_plots(opamparrays,camera, opamp, filetype='Twilight Flat',typical_sep=typical_sep,np_oper=np.sum)
        master_twiflat_data_dict[camera] = master_camera_twiflat_data_dict
        master_twiflat_header_dict[camera] = master_camera_twiflat_header_dict

    master_aux_data['twiflat'] = master_twiflat_data_dict
    master_aux_headers['twiflat'] = master_twiflat_header_dict

    print("Completed creation of master twiflat")
    print("Results saved to {}".format(common_func_vals['datadir']))
    #del twiflat_array_dict, twiflat_header_dict
# else:
#     ## load in master twilight flat
#     print("Loaded master twilight flat")
#     print("Loaded from {}".format(common_func_vals['datadir']))
    
# master_aux_data['twiflat'] = master_twiflat_data_dict
# master_aux_headers['twiflat'] = master_twiflat_header_dict   
    
filenumbers.pop('twiflat')
# Out:
# Completed creation of master twiflat
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\data_products
# array([582, 583, 584, 585, 586, 587, 588, 589, 590, 591])

# %%
if do_flat:
    for datatype in data.keys():
        datadict = data[datatype]
        headerdict = headers[datatype]
        for camera,camera_data_dict in datadict.items():
            for opamp,opamparrays in camera_data_dict.items():
                master_twiflat = master_twiflat_data_dict[camera][opamp]
                for filnum,filearray in opamparrays.items():
                    opamparray = opamparrays[filnum].astype(float)
                    header = headerdict[camera][opamp][filnum]
                    opamparray /= master_twiflat.astype(float)
                    header.add_history("Flat correction done by quickreduce on {}".format(date))
                    outhdu = fits.PrimaryHDU(data=opamparray ,header=header)
                    filename = valadded_filename_template.format(cam=camera, imtype=datatype, 
                                                                 maskname=mask_name, opamp=opamp, 
                                                                 filenum=filenum, tags=common_func_vals['tags'])
                    filename = os.path.join(common_func_vals['datadir'],filename)
                    outhdu.writeto(filename ,overwrite=True)           
                    headerdict[camera][opamp][filnum] = header
                    datadict[camera][opamp][filnum] = opamparray

        print("Completed flattening for {}".format(datatype))
        print("Results saved to {}".format(common_func_vals['datadir']))
# Out:
# Completed flattening for thar
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\stitched
# Completed flattening for comp
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\stitched
# Completed flattening for science
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\stitched
# Completed flattening for fibmap
# Results saved to C:\Users\kremin\OneDrive\Research\M2FSReductions\A02\stitched

# %%
if print_headers:
    print(list(headers['science'][camera][opamp].values())[0].keys)
# Out:
# <bound method Header.iterkeys of SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1024
# NAXIS2  =                 1028
# BUNIT   = 'DU/PIXEL'
# ORIGIN  = 'LCO/OCIW'
# OBSERVER= 'Bailey/Tucker/Spencer/Olsz' / observer name
# TELESCOP= 'Clay'                       / telescope
# SITENAME= 'LCO'
# SITEALT =                 2405         / meters
# SITELAT =            -29.01423
# SITELONG=            -70.69242
# TIMEZONE=                    4
# DATE-OBS= '2016-06-27'                 / UT date (start)
# UT-DATE = '2016-06-27'                 / UT date (start)
# UT-TIME = '23:33:42'                   / UT time (start) 84822 seconds
# UT-END  = '23:36:43'                   / UT time (end) 85003 seconds
# LC-TIME = '19:33:42'                   / local time (start) 70422 seconds
# NIGHT   = '27Jun2016'                  / local night
# MJD     =          57566.98174         / modified Julian day
# INSTRUME= 'M2FS'                       / instrument name
# SCALE   =                0.250         / arcsec/pixel
# EGAIN   =                0.595         / electrons/DU
# ENOISE  =                2.634         / electrons/read
# NOPAMPS =                    4         / # of op-amps
# OPAMP   =                    1         / this op-amp
# CHOFFX  =              256.000         / x-offset [arcsec]
# CHOFFY  =              257.000         / y-offset [arcsec]
# DISPAXIS=                    1         / disperser axis
# RA      = ' 14:00:54.9'                / right ascension
# RA-D    =          210.2286250         / degrees
# DEC     = ' 02:52:10.1'                / declination
# DEC-D   =            2.8694722         / degrees
# EQUINOX =           2000.00000         / of above coordinates
# EPOCH   =           2016.48902         / epoch (start)
# AIRMASS =                1.200         / airmass (start)
# ST      =              47816.8         / sidereal time: 13:16:57 (start)
# ROTANGLE=               172.73         / rotator offset angle
# TEL-AZIM=                 20.6         / telescope azimuth
# TEL-ELEV=                 56.4         / telescope elevation
# T-DOME  =                 13.5         / dome temperature [C]
# T-CELL  =                 10.9         / primary cell temperature [C]
# T-TRUSS =                 11.6         / telescope truss temperature [C]
# WX-TEMP =                 11.8         / weather station temperature [C]
# FILENAME= 'r0631c1'
# OBJECT  = 'KreminMiller A02 Test'      / object name
# COMMENT =                              / comment
# EXPTYPE = 'Object'                     / exposure type
# EXPTIME =              180.000         / exposure time
# NLOOPS  =                    1         / # of loops per sequence
# LOOP    =                    1         / # within this sequence
# BINNING = '2x2'                        / binning
# SPEED   = 'Slow'                       / readout speed
# DATASEC = '[1:1024,1:1028]'            / NOAO: data section
# TRIMSEC = '[1:1024,1:1028]'            / NOAO: trim section
# SUBRASTR= 'none'                       / full frame
# TEMPCCD =               -110.0         / CCD temperature [C]
# SHOE    = 'R'                          /
# SLIDE   = 'LoRes'                      /
# SLIDEENC=               1282.1         / slide encoder
# SLIDESTP=                80000         / slide step
# LO-ELEV = '9.2699'                     / step= -106735
# HI-AZIM = '0.67499'                    / step= 17357
# HI-ELEV = '0.70000'                    / step= 18000
# FOCUS   =                240.3         / step= 2403
# FILTER  = 'BK7'                        /
# SLITNAME= '180 um'                     /
# SLIT1   = '180 um'                     /
# SLIT2   = '180 um'                     /
# SLIT3   = '180 um'                     /
# SLIT4   = '180 um'                     /
# SLIT5   = '180 um'                     /
# SLIT6   = '180 um'                     /
# SLIT7   = '180 um'                     /
# SLIT8   = '180 um'                     /
# FF-THNE =                    0         / lamp level (0=off)
# FF-THAR =                    0         / lamp level (0=off)
# FF-NE   =                    0         / lamp level (0=off)
# FF-HGAR =                    0         / lamp level (0=off)
# FF-XE   =                    0         / lamp level (0=off)
# FF-QRTZ =                    0         / lamp level (0=off)
# PLATE   = 'Kremin_02_07_08_11_Plate2'  / plug plate name
# PLATESTP= 'Kremin_02_07_08_11_Plate2:' / plate setup
# TEMP01  =               12.800         / SH_Periscope
# TEMP02  =               13.188         / Cradle_R
# TEMP03  =               13.875         / Cradle_B
# TEMP04  =               10.688         / Echelle_R
# TEMP05  =               10.562         / Echelle_B
# TEMP06  =               10.938         / Prism_R
# TEMP07  =               10.812         / Prism_B
# TEMP08  =               10.938         / LoResGrating_R
# TEMP09  =               10.750         / LoResGrating_B
# SOFTWARE= 'Version 1.5.5 (1.0513) (Jun 21 2016, 11:38:05)'
# FITSVERS= '1.3'                        / FITS header version
# FIBER101= 'GAL162'                     / FID=125 Fab=24/1 C/H=02/01
# FIBER102= 'GAL002'                     / FID=422 Fab=24/2 C/H=02/02
# FIBER103= 'GAL150'                     / FID=22 Fab=25/10 C/H=02/03
# FIBER104= 'GAL001'                     / FID=434 Fab=24/4 C/H=02/04
# FIBER105= 'GAL148'                     / FID=123 Fab=24/5 C/H=02/05
# FIBER106= 'GAL161'                     / FID=51 Fab=24/6 C/H=02/06
# FIBER107= 'GAL149'                     / FID=430 Fab=24/7 C/H=02/07
# FIBER108= 'GAL134'                     / FID=250 Fab=24/8 C/H=02/08
# FIBER109= 'GAL153'                     / FID=272 Fab=25/3 C/H=02/09
# FIBER110= 'GAL086'                     / FID=214 Fab=25/2 C/H=02/10
# FIBER111= 'GAL125'                     / FID=128 Fab=26/8 C/H=02/11
# FIBER112= 'GAL126'                     / FID=158 Fab=26/1 C/H=02/12
# FIBER113= 'GAL068'                     / FID=40 Fab=24/13 C/H=02/13
# FIBER114= 'GAL067'                     / FID=155 Fab=26/6 C/H=02/14
# FIBER115= 'GAL087'                     / FID=428 Fab=24/15 C/H=02/15
# FIBER116= 'GAL151'                     / FID=433 Fab=24/16 C/H=02/16
# FIBER201= 'GAL019'                     / FID=368 Fab=18/1 C/H=04/01
# FIBER202= 'SKY006'                     / FID=366 Fab=18/2 C/H=04/02
# FIBER203= 'GAL051'                     / FID=13 Fab=26/10 C/H=04/03
# FIBER204= 'GAL102'                     / FID=375 Fab=18/4 C/H=04/04
# FIBER205= 'GAL122'                     / FID=345 Fab=18/5 C/H=04/05
# FIBER206= 'GAL182'                     / FID=328 Fab=18/6 C/H=04/06
# FIBER207= 'GAL168'                     / FID=326 Fab=18/7 C/H=04/07
# FIBER208= 'GAL173'                     / FID=329 Fab=18/8 C/H=04/08
# FIBER209= 'GAL093'                     / FID=350 Fab=18/9 C/H=04/09
# FIBER210= 'GAL110'                     / FID=323 Fab=18/10 C/H=04/10
# FIBER211= 'GAL013'                     / FID=322 Fab=18/11 C/H=04/11
# FIBER212= 'GAL141'                     / FID=333 Fab=18/12 C/H=04/12
# FIBER213= 'GAL034'                     / FID=331 Fab=18/13 C/H=04/13
# FIBER214= 'GAL158'                     / FID=351 Fab=18/14 C/H=04/14
# FIBER215= 'GAL035'                     / FID=330 Fab=18/15 C/H=04/15
# FIBER216= 'GAL159'                     / FID=334 Fab=18/16 C/H=04/16
# FIBER301= 'GAL018'                     / FID=325 Fab=17/1 C/H=06/01
# FIBER302= 'unplugged'                  / FID=339 Fab=17/2 C/H=06/02
# FIBER303= 'unplugged'                  / FID=335 Fab=17/3 C/H=06/03
# FIBER304= 'unplugged'                  / FID=347 Fab=17/4 C/H=06/04
# FIBER305= 'unplugged'                  / FID=348 Fab=17/5 C/H=06/05
# FIBER306= 'unplugged'                  / FID=293 Fab=17/7 C/H=06/06
# FIBER307= 'unplugged'                  / FID=282 Fab=26/15 C/H=06/07
# FIBER308= 'unplugged'                  / FID=295 Fab=17/8 C/H=06/08
# FIBER309= 'GAL069'                     / FID=8 Fab=26/3 C/H=06/09
# FIBER310= 'GAL057'                     / FID=319 Fab=17/10 C/H=06/10
# FIBER311= 'GAL143'                     / FID=290 Fab=17/11 C/H=06/11
# FIBER312= 'GAL066'                     / FID=144 Fab=26/16 C/H=06/12
# FIBER313= 'GAL171'                     / FID=292 Fab=17/13 C/H=06/13
# FIBER314= 'GAL056'                     / FID=302 Fab=17/14 C/H=06/14
# FIBER315= 'SKY001'                     / FID=320 Fab=17/15 C/H=06/15
# FIBER316= 'GAL047'                     / FID=297 Fab=17/16 C/H=06/16
# FIBER401= 'GAL073'                     / FID=280 Fab=14/1 C/H=08/01
# FIBER402= 'GAL006'                     / FID=257 Fab=14/2 C/H=08/02
# FIBER403= 'GAL074'                     / FID=285 Fab=14/3 C/H=08/03
# FIBER404= 'GAL075'                     / FID=210 Fab=23/3 C/H=08/04
# FIBER405= 'GAL061'                     / FID=194 Fab=23/7 C/H=08/05
# FIBER406= 'GAL165'                     / FID=273 Fab=14/6 C/H=08/06
# FIBER407= 'GAL167'                     / FID=264 Fab=14/7 C/H=08/07
# FIBER408= 'GAL071'                     / FID=276 Fab=14/8 C/H=08/08
# FIBER409= 'GAL059'                     / FID=277 Fab=14/9 C/H=08/09
# FIBER410= 'GAL109'                     / FID=100 Fab=23/2 C/H=08/10
# FIBER411= 'GAL105'                     / FID=287 Fab=14/11 C/H=08/11
# FIBER412= 'GAL156'                     / FID=269 Fab=14/12 C/H=08/12
# FIBER413= 'GAL155'                     / FID=268 Fab=14/13 C/H=08/13
# FIBER414= 'GAL154'                     / FID=432 Fab=23/9 C/H=08/14
# FIBER415= 'GAL108'                     / FID=252 Fab=14/15 C/H=08/15
# FIBER416= 'GAL084'                     / FID=249 Fab=14/16 C/H=08/16
# FIBER501= 'GAL072'                     / FID=374 Fab=22/14 C/H=10/01
# FIBER502= 'GAL140'                     / FID=226 Fab=13/2 C/H=10/02
# FIBER503= 'GAL128'                     / FID=256 Fab=13/3 C/H=10/03
# FIBER504= 'GAL115'                     / FID=234 Fab=13/4 C/H=10/04
# FIBER505= 'GAL037'                     / FID=229 Fab=13/5 C/H=10/05
# FIBER506= 'GAL063'                     / FID=19 Fab=25/16 C/H=10/06
# FIBER507= 'SKY000'                     / FID=225 Fab=13/7 C/H=10/07
# FIBER508= 'GAL114'                     / FID=255 Fab=13/8 C/H=10/08
# FIBER509= 'GAL079'                     / FID=232 Fab=13/9 C/H=10/09
# FIBER510= 'GAL012'                     / FID=254 Fab=13/10 C/H=10/10
# FIBER511= 'GAL146'                     / FID=235 Fab=25/11 C/H=10/11
# FIBER512= 'GAL098'                     / FID=242 Fab=13/12 C/H=10/12
# FIBER513= 'GAL097'                     / FID=246 Fab=13/13 C/H=10/13
# FIBER514= 'GAL077'                     / FID=241 Fab=13/14 C/H=10/14
# FIBER515= 'GAL124'                     / FID=231 Fab=13/15 C/H=10/15
# FIBER516= 'GAL000'                     / FID=238 Fab=13/16 C/H=10/16
# FIBER601= 'GAL020'                     / FID=185 Fab=10/1 C/H=12/01
# FIBER602= 'unplugged'                  / FID=191 Fab=10/2 C/H=12/02
# FIBER603= 'unplugged'                  / FID=190 Fab=10/3 C/H=12/03
# FIBER604= 'unplugged'                  / FID=187 Fab=11/14 C/H=12/04
# FIBER605= 'unplugged'                  / FID=197 Fab=11/10 C/H=12/05
# FIBER606= 'unplugged'                  / FID=199 Fab=11/7 C/H=12/06
# FIBER607= 'unplugged'                  / FID=198 Fab=11/6 C/H=12/07
# FIBER608= 'unplugged'                  / FID=180 Fab=10/8 C/H=12/08
# FIBER609= 'GAL138'                     / FID=182 Fab=10/9 C/H=12/09
# FIBER610= 'GAL010'                     / FID=208 Fab=11/9 C/H=12/10
# FIBER611= 'GAL096'                     / FID=189 Fab=10/11 C/H=12/11
# FIBER612= 'GAL123'                     / FID=188 Fab=10/12 C/H=12/12
# FIBER613= 'GAL139'                     / FID=183 Fab=10/13 C/H=12/13
# FIBER614= 'GAL095'                     / FID=172 Fab=10/14 C/H=12/14
# FIBER615= 'GAL099'                     / FID=173 Fab=10/15 C/H=12/15
# FIBER616= 'GAL050'                     / FID=177 Fab=10/16 C/H=12/16
# FIBER701= 'unplugged'                  / FID=179 Fab=9/1 C/H=13/01
# FIBER702= 'unplugged'                  / FID=192 Fab=9/2 C/H=13/02
# FIBER703= 'unplugged'                  / FID=170 Fab=9/3 C/H=13/03
# FIBER704= 'unplugged'                  / FID=248 Fab=22/8 C/H=13/04
# FIBER705= 'unplugged'                  / FID=314 Fab=22/2 C/H=13/05
# FIBER706= 'unplugged'                  / FID=23 Fab=9/6 C/H=13/06
# FIBER707= 'unplugged'                  / FID=17 Fab=9/7 C/H=13/07
# FIBER708= 'unplugged'                  / FID=315 Fab=22/4 C/H=13/08
# FIBER709= 'unplugged'                  / FID=213 Fab=11/1 C/H=13/09
# FIBER710= 'unplugged'                  / FID=91 Fab=9/10 C/H=13/10
# FIBER711= 'unplugged'                  / FID=402 Fab=9/11 C/H=13/11
# FIBER712= 'unplugged'                  / FID=413 Fab=9/12 C/H=13/12
# FIBER713= 'unplugged'                  / FID=120 Fab=22/3 C/H=13/13
# FIBER714= 'unplugged'                  / FID=389 Fab=9/14 C/H=13/14
# FIBER715= 'unplugged'                  / FID=407 Fab=9/15 C/H=13/15
# FIBER716= 'unplugged'                  / FID=393 Fab=9/16 C/H=13/16
# FIBER801= 'GAL100'                     / FID=101 Fab=5/1 C/H=16/01
# FIBER802= 'GAL021'                     / FID=119 Fab=5/2 C/H=16/02
# FIBER803= 'GAL104'                     / FID=147 Fab=7/7 C/H=16/03
# FIBER804= 'GAL028'                     / FID=106 Fab=5/4 C/H=16/04
# FIBER805= 'GAL016'                     / FID=99 Fab=5/5 C/H=16/05
# FIBER806= 'GAL017'                     / FID=112 Fab=5/6 C/H=16/06
# FIBER807= 'GAL026'                     / FID=127 Fab=5/7 C/H=16/07
# FIBER808= 'GAL023'                     / FID=109 Fab=5/8 C/H=16/08
# FIBER809= 'SKY005'                     / FID=104 Fab=5/9 C/H=16/09
# FIBER810= 'GAL070'                     / FID=121 Fab=5/10 C/H=16/10
# FIBER811= 'GAL015'                     / FID=131 Fab=7/10 C/H=16/11
# FIBER812= 'GAL076'                     / FID=141 Fab=7/11 C/H=16/12
# FIBER813= 'GAL094'                     / FID=116 Fab=5/13 C/H=16/13
# FIBER814= 'GAL049'                     / FID=110 Fab=5/14 C/H=16/14
# FIBER815= 'GAL091'                     / FID=153 Fab=7/2 C/H=16/15
# FIBER816= 'GAL060'                     / FID=86 Fab=5/16 C/H=16/16
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# HISTORY Bias Subtracted done by quickreduce on 2018-04-28                       >

# %%
#transforms = {4: 'l', 1: 'ul', 2: 'u', 3: 'none'}
#camloc = {4:'br',1:'ur',2:'ul',3:'bl'}

xorients = {-1:'l', 1:'r'}
yorients = {-1:'b', 1:'u'}

# %%
if do_stitch:
    if len(data.keys()) == 0:
        data, headers = get_all_filedata( filenum_dict=filenumbers, **common_func_vals )
    common_func_vals['datadir'] = stitched_dir
    common_func_vals['template'] = stitched_filename_template
    for imtype in data.keys():
        data_dict = data[imtype]
        header_dict = headers[imtype]
        for camera in data_dict.keys():
            camera_data_dict = data_dict[camera]
            camera_header_dict = header_dict[camera]
            number_exposures = len(cam_header_dict[1])
            for filenum in filenumbers[imtype]:
                img = {}
                for opamp in camera_data_dict.keys():
                    header = cam_header_dict[opamp][filenum]
                    xsign = np.sign(header['CHOFFX'])
                    ysign = np.sign(header['CHOFFY'])
                    location = yorients[ysign]+xorients[xsign]
                    if exp == 0:
                        print("Imtype: {}  Camera: {} Opamp: {} located at {}".format(imtype,camera,opamp,location))
                    img[location] = cam_data_dict[opamp][filenum]

                trans = {}
                ## Transform opamps to the correct directions
                trans['bl'] = img['bl']
                trans['br'] = np.fliplr(img['br'])
                trans['ul'] = np.flipud(img['ul'])
                trans['ur'] = np.fliplr(np.flipud(img['ur']))
                del img

                y_bl,x_bl = trans['bl'].shape
                y_ul,x_ul = trans['ul'].shape
                y_br,x_br = trans['br'].shape
                y_ur,x_ur = trans['ur'].shape

                ## Make sure the shapes work
                if y_bl != y_br or y_ul != y_ur:
                    print("yr and yl not the same")
                if x_bl != x_ul or x_br != x_ur:
                    print("xb and xu not the same")

                ## Create the full-sized image array
                merged = np.ndarray(shape=(y_bl+y_ul,x_bl+x_br))

                ## Assign the opamps to the correct region of the array
                ## bl
                merged[:y_bl,:x_bl] = trans['bl']
                ## ul
                merged[y_bl:,:x_bl] = trans['ul']
                ## br
                merged[:y_bl,x_bl:] = trans['br']
                ## ur
                merged[y_bl:,x_bl:] = trans['ur']

                opamp = 1
                header = cam_header_dict[opamp][filenum].copy()
                header['NAXIS1'] = int(y_bl+y_ul)
                header['NAXIS2'] = int(x_bl+x_br)
                header['FILENAME'] = header['FILENAME'].split('c{}'.format(opamp))[0]
                for key in ['OPAMP','CHOFFX','CHOFFY']:
                    header.remove(key)
                header.add_history("Stitched 4 opamps by quickreduce on {}".format(date))
                outhdu = fits.PrimaryHDU(data=merged ,header=header)
                filename = stitched_filename_template.format(imtype=imtype,cam=camera, filenum=filenum,
                                                             maskname=mask_name, tags=common_func_vals['tags'])
                filename = os.path.join(common_func_vals['datadir'],filename)
                outhdu.writeto(filename ,overwrite=True)

                data[imtype][camera]['stitched'][filenum] = merged
                header[imtype][camera]['stitched'][filenum] = header

                ## Plot the image
                plt.figure()
                merged = merged - np.min(merged) + 1e-4
                plt.imshow(np.log(merged),'gray',origin='lowerleft')
                plt.savefig(filename.replace('.fits','.png'),dpi=1200)
                plt.show()
            for opamp in opamps:
                data[imtype][camera].remove(opamp)
                header[imtype][camera].remove(opamp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-d68e4a35b597> in <module>()
#      10             camera_data_dict = data_dict[camera]
#      11             camera_header_dict = header_dict[camera]
# ---> 12             number_exposures = len(cam_header_dict[1])
#      13             for filenum in filenumbers[imtype]:
#      14                 img = {}
#
# NameError: name 'cam_header_dict' is not defined

# %%
common_func_vals['opamps'] = 'stitched'

# %%
from quickreduce_funcs import get_all_stitcheddata

if do_apcut:
    if len(data.keys()) == 0:
        data, headers = get_all_stitcheddata( filnum_dict=filenumbers, **common_func_vals )
    if fibermap_array_dict is None or 'fibmap' in data.keys():
        fibermap_array_dict = data.pop('fibmap')
        fibermap_header_dict = headers.pop('fibmap')
    else:
        print("Can't find the fiber maps!")

# %%
if do_apcut:
    master_fibm_data_dict = {}
    master_fibm_header_dict = {}

    for camera,camera_data_dict in fibermap_array_dict.items():
        
        opamp = 'stitched'
        
        heads = fibm_header_dict[camera][opamp]
        master_bias = master_bias_data_dict[camera][opamp]
        header = list(heads.values())[0]
        
        if header['SHOE'].lower() != camera:
            print("In fibermap: Camera did not match the header's shoe variable")
        if header['OPAMP'] != opamp:
            print("In fibermap: Opamp did not match the header's opamp variable")
            
        
        opamparray = np.asarray(list(heads.values())).sum(axis=0)
        header.add_history("Master fibermap done by quickreduce on {}".format(date))
        
        outhdu = fits.PrimaryHDU(data=opamparray ,header=header)  
        outname = master_stitched_fname_template.format(cam=camera, imtype="fibermap", 
                                                        maskname=mask_name, 
                                                        tags=common_func_vals['tags'])
        outname = os.path.join(common_func_vals['dirname'],outname)
        outhdu.writeto( outname ,overwrite=True)

        if make_debug_plots:
            typical_sep = np.mean(opamparrays[0,:,:])- np.mean(opamparrays[-1,:,:])
            if typical_sep < 10:
                typical_sep = 10
            debug_plots(opamparrays,camera, opamp, filetype='Fibermap',typical_sep=typical_sep,np_oper=np.sum)
        master_fibm_data_dict[camera] = opamparray
        master_fibm_header_dict[camera] = header

    master_aux_data['fibmap'] = master_fibm_data_dict
    master_aux_headers['fibmap'] = master_fibm_header_dict

    print("Completed master fibermap")
    print("Results saved to {}".format(common_func_vals['datadir']))
    #del fibm_array_dict, fibm_header_dict

# else:
#     ## load in master fibermap
#     print("Loaded master fibermap")
#     print("Loaded from {}".format(common_func_vals['datadir']))
    
# master_aux_data['bias'] = master_fibm_data_dict
# master_aux_headers['bias'] = master_fibm_header_dict       
    
filenumbers.pop('fibmap')

# %%
common_func_vals['datadir'] = stitched_dir
common_func_vals['template'] = stitched_filename_template
